# %% [markdown]
# # Matplotlib
#
# Matplotlib is a powerful plotting library in Python used for creating static, animated, and interactive visualizations. Matplotlib’s primary purpose is to provide users with the tools and functionality to represent data graphically, making it easier to analyze and understand. It was originally developed by John D. Hunter in 2003 and is now maintained by a large community of developers.
#
# Pyplot is a Matplotlib module that provides a MATLAB-like interface. Matplotlib is designed to be as usable as MATLAB, with the ability to use Python and the advantage of being free and open-source. Each pyplot function makes some changes to a figure.

# %%
# %matplotlib inline                                           
# it presents all the charts and graphs right here. it's used coz plt.show won't work as this is a browser

# %%
from matplotlib import pyplot as plt                                      # pip install matplotlib
from matplotlib import style

# %%
#style.use('ggplot')                                   # graph style             # commented it out coz it was styling all the graphs

a = [2, 4, 5]
b = [3, 5, 7]
c = [2, 6, 9]
d = [4, 5, 8]

# first call to plt.plot creates the axes(region of the image with the data space),
# then subsequent calls to plt.plot add additional lines on the same axes

plt.plot(a,b, label='A', linewidth =3)                  # plots (2,3), (4, 5), (5, 7) on the graph
plt.plot(c, d, label='B')
plt.legend()                                            # for the legends
plt.xlabel("X-axis")                                    # names the x-axis
plt.ylabel("Y-axis")                                    # names the y-axis
plt.title('Line Graph')                                 # title
plt.show()

# %%
plt.scatter([3, 4, 9, 7], [3, 6, 8, 5])
plt.hist([5, 6, 8])
# Out:
# (array([1., 0., 0., 1., 0., 0., 0., 0., 0., 1.]),
#  array([5. , 5.3, 5.6, 5.9, 6.2, 6.5, 6.8, 7.1, 7.4, 7.7, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot([8, 0, 4, 8, 0, 8], [5, 0, 8, 0, 5, 5])

# %% [markdown]
# --------------------------------
#
# --> Matplotlib basically plots and visualizes data.
#
# --> For this the data must be in numpy array.

# %%
import numpy as np

x = np.arange(0, 10, 0.2)
y = np.sin(x)

print("X : ", x)
print("Y : ", y)
# Out:
# X :  [0.  0.2 0.4 0.6 0.8 1.  1.2 1.4 1.6 1.8 2.  2.2 2.4 2.6 2.8 3.  3.2 3.4
#  3.6 3.8 4.  4.2 4.4 4.6 4.8 5.  5.2 5.4 5.6 5.8 6.  6.2 6.4 6.6 6.8 7.
#  7.2 7.4 7.6 7.8 8.  8.2 8.4 8.6 8.8 9.  9.2 9.4 9.6 9.8]
# Y :  [ 0.          0.19866933  0.38941834  0.56464247  0.71735609  0.84147098
#   0.93203909  0.98544973  0.9995736   0.97384763  0.90929743  0.8084964
#   0.67546318  0.51550137  0.33498815  0.14112001 -0.05837414 -0.2555411
#  -0.44252044 -0.61185789 -0.7568025  -0.87157577 -0.95160207 -0.993691
#  -0.99616461 -0.95892427 -0.88345466 -0.77276449 -0.63126664 -0.46460218
#  -0.2794155  -0.0830894   0.1165492   0.31154136  0.49411335  0.6569866
#   0.79366786  0.8987081   0.96791967  0.99854335  0.98935825  0.94073056
#   0.85459891  0.7343971   0.58491719  0.41211849  0.22288991  0.02477543
#  -0.17432678 -0.36647913]

# %% [markdown]
# Two ways to create and visualize plots
#
# 1. Explicitly create figure and axis
# 2. Use pyplot

# %%
fig, ax = plt.subplots()     # create a figure and an axes

ax.plot(x, y, label= 'linear')

# %%
plt.plot(x, y, label='linear')

# %%
plt.close()

# %%
yy = np.cos(x)

# %%
plt.plot(x, y, label='Sine', linewidth=4)
plt.plot(x, yy, label='Cos')
plt.plot(x, yy, label='Cos2')

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Simple Plot')
# Out:
# Text(0.5, 1.0, 'Simple Plot')

# %% [markdown]
# ##### Plotting Subplots

# %%
plt.subplot(2, 1, 1)         # (rows, column, plot no)
plt.plot(x, y)
plt.title("Sine Plot")

plt.subplot(2, 1, 2)
plt.plot(x, yy)
plt.title("Cos Plot")
# Out:
# Text(0.5, 1.0, 'Cos Plot')

# %% [markdown]
# -------------------
#
# ## Plotting Images
#
# An image is a 2D array or can say, a grid of values which are arranged in rows and columns.
#
# Before x, y both were 1D now it's 2D so 'plt.plot' function can't be used.
# For this there's function called 'plt.imshow'
#
# Importing image data into numpy arrays

# %%
import matplotlib.image as mpimg
import os

# %%
img = mpimg.imread(r"C:\Users\shubh\Downloads\Baby Dragon.jpg")

img.shape
# Out:
# (1104, 736, 3)

# %%
img[0].shape
# Out:
# (736, 3)

# %%
img_plot = plt.imshow(img)

# %% [markdown]
# --------

# %% [markdown]
# ## Plotting Different Graphs
#
# ### 1.  Line Graph
#
# Line graphs are commonly used to visualize trends over time or relationships between variables.
#
# A line plot is a type of plot that displays info as a series of data points connected by straight lines.
#
# * Visualizing trends and changes over time
# * Showing relationships
# * Compare multiple data series
# * Highlighting sudden changes or anomalies
#
# First one was an example of Line Graph.

# %% [raw]
# import matplotlib.pyplot as plt
#
# dataframe.loc['Name', name].plot(kind = 'line')     # hope you are sensible enough to import a file into pandas dataframe first
# plt.title('Title')
# plt.xlabel('xlabel')
# plt.ylabel('ylabel')
#
# plt.show()

# %% [markdown]
# ### 2.  Bar Chart
#
# A bar plot or bar chart is a graph that represents the category of data with rectangular bars with lengths and heights that is proportional to the values which they represent. The bar plots can be plotted horizontally or vertically. A bar chart describes the comparisons between the discrete categories.
#
# It can be created using the bar() method.
#
# * Also known as a bar graph
# * Compares the value of variable

# %% [raw]
# dataframe.plot(kind = 'bar')
# plt.title('Title')
# plt.xlabel('xlabel')
# plt.ylabel('ylabel')
#
# plt.show()

# %%
x = [3, 1, 3, 10, 2, 4, 4] 
y = [2, 1, 1, 3, 4, 5, 6] 
plt.bar(x, y)
plt.title("Bar Chart")
plt.show()

# %% [markdown]
# ### 3. Scatter Chart
#
# Scatter plots are ideal for visualizing the relationship between two continuous variables.
#
# * Displays values pertaining to two variables
# * Determines the correlation between the two variables

# %% [raw]
# dataframe.plot(kind = 'scatter', x='Coulmn', y='Column')
# plt.title('Title')
# plt.xlabel('xlabel')
# plt.ylabel('ylabel')
#
# plt.show()

# %%
x = [3, 1, 2, 8, 2, 4, 6]
y = [2, 1, 1, 3, 4, 5, 3]
plt.scatter(x, y)
plt.title("Scatter chart")
plt.show()

# %% [markdown]
# ### 4. Area Plot
#
# * Also known as **Area Chart** or **Area Graph**
# * Displays magnitude and proportion of multiple values
# * Represents time or another ordered dimension
# * Is based on the line plot

# %% [raw]
# dataframe.plot(kind = 'area')
# plt.title('Title')
# plt.xlabel('xlabel')
# plt.ylabel('ylabel')
#
# plt.show()

# %% [markdown]
# ### 5. Histograms
#
# * Represents the frequency distribution of the dataset
#    - partitions numeric data into bins
#    - assigns each data point in the data set
#    - counts the number of data poins

# %% [raw]
# dataframe.plot(kind = 'hist')
# plt.title('Title')
# plt.xlabel('xlabel')
# plt.ylabel('ylabel')
#
# plt.show()

# %% [markdown]
# ### 6. Pie Chart
#
# A circular statistical graphic, divided into segments to illustrate numerical proportions

# %% [raw]
# dataframe['Column'].plot(kind = 'pie')
# plt.title('Title')
#
# plt.show()

# %% [markdown]
# ### 7. Box Plot
#
# A box plot is a way of statistically representing given data distribution through five main dimensions.
#
# The five main dimensions are minimum, first quartile, median, third quartile, and maximum.

# %% [raw]
# dataframe.plot(kind = 'box')
# plt.title('Title')
# plt.ylabel('ylabel')
#
# plt.show()

# %% [markdown]
# ### 8. Pivot Charts
#
# * Pivot charts are a powerful tool used for data visualization and analysis.
# * They allow users to dynamically summarize and explore large datasets, revealing insights and trends that might not be immediately obvious.
# * Pivot charts are widely used in business intelligence, finance, marketing, and various other fields where data analysis is crucial.

# %% [raw]
# pivot_table = dataframe.pivot_table(values='ValueColumn', index='RowIndexColumn', columns='ColumnIndexColumn', aggfunc='sum')
#
# pivot_table.plot(kind='bar')
# plt.title('Pivot Chart Title')
# plt.xlabel('X-axis Label')
# plt.ylabel('Y-axis Label')
# plt.show()
